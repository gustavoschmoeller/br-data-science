# %% [markdown]
# ## Importando dados localmente

# %% [markdown]
# ### Como importar CSV

# %%
import pandas as pd

import sys
IN_COLAB = 'google.colab' in sys.modules

# %%
if IN_COLAB:
  import os
  os.system('git clone https://github.com/awarischool/br-data-science') # Clona o repositório da br-data-science 
  os.chdir('br-data-science/data-collection/') # Muda o diretório de leitura dos arquivos

# %%
ls
# Out:
# Data_Collection_Notebook.ipynb  meu_arquivo.jpg  meu_arquivo.xlsx
# meu_arquivo.csv                 meu_arquivo.txt  selenium/

# %%
pd.read_csv('meu_arquivo.csv')
# Out:
#   col1;col2;col3;col4
# 0     221;956;796;136
# 1     879;696;875;617
# 2     725;303;363;780
# 3     538;840;247;178

# %%
# csv: comma- , - separated values 
df_csv = pd.read_csv('meu_arquivo.csv', sep=';')

# %%
df_csv
# Out:
#    col1  col2  col3  col4
# 0   221   956   796   136
# 1   879   696   875   617
# 2   725   303   363   780
# 3   538   840   247   178

# %%
type(df_csv)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Como importar XLSX

# %%
df_excel = pd.read_excel('meu_arquivo.xlsx')

# %%
df_excel
# Out:
#    col1  col2  col3  col4
# 0   221   956   796   136
# 1   879   696   875   617
# 2   725   303   363   780
# 3   538   840   247   178

# %% [markdown]
# ### Como importar TXT

# %%
# open('meu_arquivo.txt')

# %%
arquivo = open('meu_arquivo.txt')

# %%
arquivo.read()
# Out:
# '\ufeffOlá mundo!\nSou um arquivo .txt!\n'

# %%
arquivo.close()

# %%
# abrindo o arquivo para resolver o encoding
arquivo = open('meu_arquivo.txt', encoding='utf8')

# %%
arquivo.read()
# Out:
# '\ufeffOlá mundo!\nSou um arquivo .txt!\n'

# %%
arquivo.close()

# %%
arquivo = open('meu_arquivo.txt', encoding='utf8')

# %%
print(arquivo.read())
# Out:
# ﻿Olá mundo!
# Sou um arquivo .txt!

# %%
arquivo.close()

# %%
with open('meu_arquivo.txt', encoding='utf8') as arquivo:
    print(arquivo.read())
# Out:
# ﻿Olá mundo!
# Sou um arquivo .txt!

# %% [markdown]
# ### Como importar fotos

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('meu_arquivo.jpg')

# %%
plt.imshow(img)
plt.axis('off');

# %% [markdown]
# ## Importando dados da internet

# %% [markdown]
# ### Repositorio de Arquivos

# %%
pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
# Out:
#     Province/State      Country/Region        Lat  ...  12/16/20  12/17/20  12/18/20
# 0              NaN         Afghanistan  33.939110  ...     38475     38505     38540
# 1              NaN             Albania  41.153300  ...     26381     26898     27426
# 2              NaN             Algeria  28.033900  ...     61700     62089     62487
# 3              NaN             Andorra  42.506300  ...      6819      6875      6919
# 4              NaN              Angola -11.202700  ...      9194      9266      9345
# ..             ...                 ...        ...  ...       ...       ...       ...
# 251            NaN             Vietnam  14.058324  ...      1252      1263      1266
# 252            NaN  West Bank and Gaza  31.952200  ...     90952     92979     94556
# 253            NaN               Yemen  15.552727  ...      1384      1384      1384
# 254            NaN              Zambia -13.133897  ...     17635     17680     17729
# ...

# %%
link = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'

# %%
df_jh = pd.read_csv(link)

# %%
df_jh.head()
# Out:
#   Province/State Country/Region       Lat  ...  12/16/20  12/17/20  12/18/20
# 0            NaN    Afghanistan  33.93911  ...     38475     38505     38540
# 1            NaN        Albania  41.15330  ...     26381     26898     27426
# 2            NaN        Algeria  28.03390  ...     61700     62089     62487
# 3            NaN        Andorra  42.50630  ...      6819      6875      6919
# 4            NaN         Angola -11.20270  ...      9194      9266      9345
#
# [5 rows x 336 columns]

# %% [markdown]
# #### XLSX

# %%
url_excel = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSc5G7yKDMcF52ITyQdG9oABCV1Ix4N6s-tMUX50c3H0VswP1DUvww3PU8KNV1n-25ie58K2vBC7cVE/pub?output=xlsx'

# %%
df_excel = pd.read_excel(url_excel)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-37-fbb09adc2468> in <module>()
# ----> 1 df_excel = pd.read_excel(url_excel)
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# ...

# %%
df_excel
# Out:
#    col1  col2  col3  col4
# 0   221   956   796   136
# 1   879   696   875   617
# 2   725   303   363   780
# 3   538   840   247   178

# %% [markdown]
# ### Imagens

# %% [markdown]
# PIL --> Pillow
#
# !pip install pillow

# %%
from PIL import Image
import requests
from io import BytesIO

url = 'https://network.grupoabril.com.br/wp-content/uploads/sites/4/2020/02/desafio-jedi-de-mestre-yoda-consertar-as-frases-consegue-vocecc82.jpg'
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x800 at 0x7F2B9D9F2FD0>
